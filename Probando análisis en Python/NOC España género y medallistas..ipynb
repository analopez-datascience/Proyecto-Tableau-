# %%
import warnings
warnings.filterwarnings("ignore")

import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Cargar el archivo CSV
file_path = './athlete_events.csv'
df = pd.read_csv(file_path)

# Filtrar por NOC de España y filas donde hay medallas
df_esp_medallas = df[(df['NOC'] == 'ESP') & (df['Medal'].notna())]

# Obtener la lista de nombres de los medallistas femeninos y masculinos
medallistas_femeninos = df_esp_medallas[df_esp_medallas['Sex'] == 'F']['Name'].unique().tolist()
medallistas_masculinos = df_esp_medallas[df_esp_medallas['Sex'] == 'M']['Name'].unique().tolist()

print("Medallistas Femeninos de España:")
print(medallistas_femeninos)

print("\nMedallistas Masculinos de España:")
print(medallistas_masculinos)
# Out:
# Medallistas Femeninos de España:
# ...

# %%
# Filtrar por NOC de España y filas donde hay medallas
df_esp_medallas = df[(df['NOC'] == 'ESP') & (df['Medal'].notna())]

# Obtener la lista de nombres de los medallistas femeninos y masculinos
medallistas_femeninos = df_esp_medallas[df_esp_medallas['Sex'] == 'F']['Name'].unique().tolist()
medallistas_masculinos = df_esp_medallas[df_esp_medallas['Sex'] == 'M']['Name'].unique().tolist()

medallistas_femeninos, #medallistas_masculinos
# Out:
# (['Macarena Aguilar Daz',
#   'Sandra Aguilar Navarro',
#   'Marina Alabau Neira',
#   'Nely Carla Alberto Francisca',
#   'Jessica Alonso Bernardo',
#   'Vanessa Amors Quiles',
#   'Sandra Azn Canalda',
#   'Marta Bach Pascual',
#   'Marta Bald Marn',
#   'Mara del Carmen Barea Cobos',
#   'Andrea Barno San Martn',
#   'Sonia Barrio Gutirrez',
#   'Clara Basiana Caellas',
#   'Ruth Beita Vila',
#   'Mireia Belmonte Garca',
#   'Andrea Blas Martnez',
#   'Mriam Guadalupe Blasco Soto',
#   'Nuria Cabanillas Provencio',
#   'Alba Mara Cabello Rodilla',
#   'Eva Calvo Gmez',
#   'Ona Carbonell Ballestero',
#   'Maialen Chourraut Yurramendi',
#   'Mihaela Ciobanu Ciobanu',
#   'Mercedes Coghen Alberdingk-Thijm',
#   'Raquel Corral Aznar',
#   'Margalida Cresp Jaume',
#   'Anna Cruz Lebrato',
#   'Vernica Mara Cuadrado Dehesa',
#   'Slvia Domnguez Fernndez',
#   'Natalia Dorado Gmez',
#   'Tmara Echegoyen Domnguez',
#   'Patricia Elorza Eguiara',
#   'Anna Espar Llaquet',
# ...

# %%
medallistas_femeninos
# Out:
# ['Macarena Aguilar Daz',
#  'Sandra Aguilar Navarro',
#  'Marina Alabau Neira',
#  'Nely Carla Alberto Francisca',
#  'Jessica Alonso Bernardo',
#  'Vanessa Amors Quiles',
#  'Sandra Azn Canalda',
#  'Marta Bach Pascual',
#  'Marta Bald Marn',
#  'Mara del Carmen Barea Cobos',
#  'Andrea Barno San Martn',
#  'Sonia Barrio Gutirrez',
#  'Clara Basiana Caellas',
#  'Ruth Beita Vila',
#  'Mireia Belmonte Garca',
#  'Andrea Blas Martnez',
#  'Mriam Guadalupe Blasco Soto',
#  'Nuria Cabanillas Provencio',
#  'Alba Mara Cabello Rodilla',
#  'Eva Calvo Gmez',
#  'Ona Carbonell Ballestero',
#  'Maialen Chourraut Yurramendi',
#  'Mihaela Ciobanu Ciobanu',
#  'Mercedes Coghen Alberdingk-Thijm',
#  'Raquel Corral Aznar',
#  'Margalida Cresp Jaume',
#  'Anna Cruz Lebrato',
#  'Vernica Mara Cuadrado Dehesa',
#  'Slvia Domnguez Fernndez',
#  'Natalia Dorado Gmez',
#  'Tmara Echegoyen Domnguez',
#  'Patricia Elorza Eguiara',
#  'Anna Espar Llaquet',
#  'Laura Ester Ramos',
# ...

# %%
# Filtrar por NOC de España y filas donde hay medallas
df_esp_medallas = df[(df['NOC'] == 'ESP') & (df['Medal'].notna())]

# Seleccionar las columnas relevantes
medallistas_esp = df_esp_medallas[['Name', 'Sex', 'Sport', 'Medal']]

# Obtener la lista de nombres de los medallistas femeninos y masculinos junto con el deporte y el tipo de medalla
medallistas_femeninos = medallistas_esp[medallistas_esp['Sex'] == 'F']
medallistas_masculinos = medallistas_esp[medallistas_esp['Sex'] == 'M']

print("Medallistas Femeninos de España con Deporte y Tipo de Medalla:")
print(medallistas_femeninos.head(50))  # Muestra los primeros 10 para ilustración

#print("\nMedallistas Masculinos de España con Deporte y Tipo de Medalla:")
#print(medallistas_masculinos.head(10))  # Muestra los primeros 10 para ilustración
# Out:
# Medallistas Femeninos de España con Deporte y Tipo de Medalla:
#                                       Name Sex                  Sport   Medal
# 2263                  Macarena Aguilar Daz   F               Handball  Bronze
# 2280                Sandra Aguilar Navarro   F    Rhythmic Gymnastics  Silver
# 3833                   Marina Alabau Neira   F                Sailing    Gold
# 4067          Nely Carla Alberto Francisca   F               Handball  Bronze
# 5350               Jessica Alonso Bernardo   F               Handball  Bronze
# 6248                  Vanessa Amors Quiles   F               Handball  Bronze
# 11645                   Sandra Azn Canalda   F                Sailing  Silver
# 11953                   Marta Bach Pascual   F             Water Polo  Silver
# 13309                      Marta Bald Marn   F    Rhythmic Gymnastics    Gold
# 14550          Mara del Carmen Barea Cobos   F                 Hockey    Gold
# ...

# %%
# Seleccionar las columnas relevantes
medallistas_esp = df_esp_medallas[['Name', 'Sex', 'Sport', 'Medal']]

# Obtener la lista de nombres de los medallistas femeninos y masculinos junto con el deporte y el tipo de medalla
medallistas_femeninos = medallistas_esp[medallistas_esp['Sex'] == 'F']
medallistas_masculinos = medallistas_esp[medallistas_esp['Sex'] == 'M']

medallistas_femeninos.head(10), medallistas_masculinos.head(10)
# Out:
# (                               Name Sex                Sport   Medal
#  2263           Macarena Aguilar Daz   F             Handball  Bronze
#  2280         Sandra Aguilar Navarro   F  Rhythmic Gymnastics  Silver
#  3833            Marina Alabau Neira   F              Sailing    Gold
#  4067   Nely Carla Alberto Francisca   F             Handball  Bronze
#  5350        Jessica Alonso Bernardo   F             Handball  Bronze
#  6248           Vanessa Amors Quiles   F             Handball  Bronze
#  11645            Sandra Azn Canalda   F              Sailing  Silver
#  11953            Marta Bach Pascual   F           Water Polo  Silver
#  13309               Marta Bald Marn   F  Rhythmic Gymnastics    Gold
#  14550   Mara del Carmen Barea Cobos   F               Hockey    Gold,
#                                   Name Sex       Sport   Medal
#  159               Jos Luis Abajo Gmez   M     Fencing  Bronze
#  182            Jos Mara Abarca Plotas   M  Water Polo    Gold
# ...

# %%
# Filtrar por NOC de España, medallas de oro y sexo femenino
df_esp_medallas_gold_femenino = df[(df['NOC'] == 'ESP') & (df['Medal'] == 'Gold') & (df['Sex'] == 'F')]

# Seleccionar las columnas relevantes
medallistas_gold_femeninos = df_esp_medallas_gold_femenino[['Name', 'Sport', 'Medal']]

print("Medallistas Femeninas de Oro de España:")
print(medallistas_gold_femeninos)
# Out:
# Medallistas Femeninas de Oro de España:
#                                                   Name                Sport  \
# 3833                               Marina Alabau Neira              Sailing
# 13309                                  Marta Bald Marn  Rhythmic Gymnastics
# 14550                      Mara del Carmen Barea Cobos               Hockey
# 15067                            Sonia Barrio Gutirrez               Hockey
# 17793                                  Ruth Beita Vila            Athletics
# 18414                            Mireia Belmonte Garca             Swimming
# 23166                      Mriam Guadalupe Blasco Soto                 Judo
# 33267                       Nuria Cabanillas Provencio  Rhythmic Gymnastics
# 41074                     Maialen Chourraut Yurramendi             Canoeing
# 43142                 Mercedes Coghen Alberdingk-Thijm               Hockey
# 57515                              Natalia Dorado Gmez               Hockey
# ...

# %%
# Filtrar por NOC de España, medallas de oro y sexo femenino
df_esp_medallas_gold_femenino = df[(df['NOC'] == 'ESP') & (df['Medal'] == 'Gold') & (df['Sex'] == 'F')]

# Seleccionar las columnas relevantes
medallistas_gold_femeninos = df_esp_medallas_gold_femenino[['Name', 'Sport', 'Medal']]

medallistas_gold_femeninos
# Out:
#                                                   Name                Sport  \
# 3833                               Marina Alabau Neira              Sailing
# 13309                                  Marta Bald Marn  Rhythmic Gymnastics
# 14550                      Mara del Carmen Barea Cobos               Hockey
# 15067                            Sonia Barrio Gutirrez               Hockey
# 17793                                  Ruth Beita Vila            Athletics
# 18414                            Mireia Belmonte Garca             Swimming
# 23166                      Mriam Guadalupe Blasco Soto                 Judo
# 33267                       Nuria Cabanillas Provencio  Rhythmic Gymnastics
# 41074                     Maialen Chourraut Yurramendi             Canoeing
# 43142                 Mercedes Coghen Alberdingk-Thijm               Hockey
# 57515                              Natalia Dorado Gmez               Hockey
# ...

# %%
# Filtrar por NOC de España, medallas de oro, sexo femenino
df_esp_medallas_gold_femenino = df[(df['NOC'] == 'ESP') & (df['Medal'] == 'Gold') & (df['Sex'] == 'F')]

# Seleccionar las columnas relevantes
medallistas_gold_femeninos = df_esp_medallas_gold_femenino[['Name', 'Year', 'Sport', 'Medal']]

print("Medallistas Femeninas de Oro de España:")
print(medallistas_gold_femeninos)
# Out:
# Medallistas Femeninas de Oro de España:
#                                                   Name  Year  \
# 3833                               Marina Alabau Neira  2012
# 13309                                  Marta Bald Marn  1996
# 14550                      Mara del Carmen Barea Cobos  1992
# 15067                            Sonia Barrio Gutirrez  1992
# 17793                                  Ruth Beita Vila  2016
# 18414                            Mireia Belmonte Garca  2016
# 23166                      Mriam Guadalupe Blasco Soto  1992
# 33267                       Nuria Cabanillas Provencio  1996
# 41074                     Maialen Chourraut Yurramendi  2016
# 43142                 Mercedes Coghen Alberdingk-Thijm  1992
# 57515                              Natalia Dorado Gmez  1992
# 61093                         Tmara Echegoyen Domnguez  2012
# 68166                    Mara Isabel Fernndez Gutirrez  2000
# 74379                        Nagore Gabellanes Marieta  1992
# ...

# %%
# Seleccionar las columnas relevantes
medallistas_gold_femeninos = df_esp_medallas_gold_femenino[['Name', 'Year', 'Sport', 'Medal']]

medallistas_gold_femeninos
# Out:
#                                                   Name  Year  \
# 3833                               Marina Alabau Neira  2012
# 13309                                  Marta Bald Marn  1996
# 14550                      Mara del Carmen Barea Cobos  1992
# 15067                            Sonia Barrio Gutirrez  1992
# 17793                                  Ruth Beita Vila  2016
# 18414                            Mireia Belmonte Garca  2016
# 23166                      Mriam Guadalupe Blasco Soto  1992
# 33267                       Nuria Cabanillas Provencio  1996
# 41074                     Maialen Chourraut Yurramendi  2016
# 43142                 Mercedes Coghen Alberdingk-Thijm  1992
# 57515                              Natalia Dorado Gmez  1992
# 61093                         Tmara Echegoyen Domnguez  2012
# 68166                    Mara Isabel Fernndez Gutirrez  2000
# 74379                        Nagore Gabellanes Marieta  1992
# ...

# %% [markdown]
# # Medallistas ORO Femeninas

# %%
# Ordenar por el año
medallistas_gold_femeninos_sorted = medallistas_gold_femeninos.sort_values(by='Year')

medallistas_gold_femeninos_sorted
# Out:
#                                                   Name  Year  \
# 57515                              Natalia Dorado Gmez  1992
# 146817                             Anna Maiques i Dern  1992
# 267024                            Theresa Zabell Lucas  1992
# 85968                          Patricia Guerra Cabrera  1992
# 81940           Mara Victoria "Mariv" Gonzlez Laguillo  1992
# 151051  Mara Isabel "Maribel" Martnez de Murgua Embara  1992
# 74379                        Nagore Gabellanes Marieta  1992
# 164375                              Teresa Motos Izeta  1992
# 165885                           Almudena Muoz Martnez  1992
# 148663                            Silvia Manrique Prez  1992
# 148927                Elisabeth "Eli" Maragall i Verge  1992
# 176431                              Nria Oliv Vancells  1992
# 196562                          Virginia Ramrez Medino  1992
# 23166                      Mriam Guadalupe Blasco Soto  1992
# ...

# %% [markdown]
# # Medallistas SILVER femeninas

# %%
# Filtrar por NOC de España, medallas de plata, sexo femenino
df_esp_medallas_silver_femenino = df[(df['NOC'] == 'ESP') & (df['Medal'] == 'Silver') & (df['Sex'] == 'F')]

# Seleccionar las columnas relevantes y ordenar por el año
medallistas_silver_femeninos_sorted = df_esp_medallas_silver_femenino[['Name', 'Year', 'Sport', 'Medal']].sort_values(by='Year')

print("Medallistas Femeninas de Plata de España ordenadas por Año:")
print(medallistas_silver_femeninos_sorted)
# Out:
# Medallistas Femeninas de Plata de España ordenadas por Año:
#                                                 Name  Year  \
# 252130                     Natalia Va Dufresne Perea  1992
# 150869                       Conchita Martnez Bernat  1992
# 209620  Arnzazu Isabel Mara "Arantxa" Snchez Vicario  1992
# 182821                        Carolina Pascual Garca  1992
# 209621  Arnzazu Isabel Mara "Arantxa" Snchez Vicario  1996
# 68632            Beatriz Ferrer-Salat Serra de Migui  2004
# 11645                             Sandra Azn Canalda  2004
# 252132                     Natalia Va Dufresne Perea  2004
# 150875                       Conchita Martnez Bernat  2004
# 205476                 Virginia "Vivi" Ruano Pascual  2004
# 195137                    Mara Quintanal Zubizarreta  2004
# 142327                              Laura Lpez Valle  2008
# 94297                          Thais Henrquez Torres  2008
# 73686                           Andrea Fuentes Fache  2008
# ...

# %%
# Filtrar por NOC de España, medallas de plata y sexo femenino
df_esp_medallas_silver_femenino = df[(df['NOC'] == 'ESP') & (df['Medal'] == 'Silver') & (df['Sex'] == 'F')]

# Seleccionar las columnas relevantes y ordenar por el año
medallistas_silver_femeninos_sorted = df_esp_medallas_silver_femenino[['Name', 'Year', 'Sport', 'Medal']].sort_values(by='Year')

medallistas_silver_femeninos_sorted
# Out:
#                                                 Name  Year  \
# 252130                     Natalia Va Dufresne Perea  1992
# 150869                       Conchita Martnez Bernat  1992
# 209620  Arnzazu Isabel Mara "Arantxa" Snchez Vicario  1992
# 182821                        Carolina Pascual Garca  1992
# 209621  Arnzazu Isabel Mara "Arantxa" Snchez Vicario  1996
# 68632            Beatriz Ferrer-Salat Serra de Migui  2004
# 11645                             Sandra Azn Canalda  2004
# 252132                     Natalia Va Dufresne Perea  2004
# 150875                       Conchita Martnez Bernat  2004
# 205476                 Virginia "Vivi" Ruano Pascual  2004
# 195137                    Mara Quintanal Zubizarreta  2004
# 142327                              Laura Lpez Valle  2008
# 94297                          Thais Henrquez Torres  2008
# 73686                           Andrea Fuentes Fache  2008
# 73685                           Andrea Fuentes Fache  2008
# ...

# %% [markdown]
# # Medallistas BRONZE femeninas

# %%
# Filtrar por NOC de España, medallas de bronce, sexo femenino
df_esp_medallas_bronze_femenino = df[(df['NOC'] == 'ESP') & (df['Medal'] == 'Bronze') & (df['Sex'] == 'F')]

# Seleccionar las columnas relevantes y ordenar por el año
medallistas_bronze_femeninos_sorted = df_esp_medallas_bronze_femenino[['Name', 'Year', 'Sport', 'Medal']].sort_values(by='Year')

print("Medallistas Femeninas de Bronce de España ordenadas por Año:")
print(medallistas_bronze_femeninos_sorted)
# Out:
# Medallistas Femeninas de Bronce de España ordenadas por Año:
#                                                 Name  Year  \
# 68318                          Blanca Fernndez Ochoa  1992
# 209619  Arnzazu Isabel Mara "Arantxa" Snchez Vicario  1992
# 150871                       Conchita Martnez Bernat  1996
# 224767                         Yolanda Soler Grajera  1996
# 209622  Arnzazu Isabel Mara "Arantxa" Snchez Vicario  1996
# 68165                  Mara Isabel Fernndez Gutirrez  1996
# 250302              Mara del Monte Vasc Pes Gallardo  2000
# 269334     Nina Alexandrovna Zhivanevskaya Ilichiova  2000
# 73986                Margarita "Marga" Fullana Riera  2000
# 163298                        Patricia Moreno Snchez  2004
# 68631            Beatriz Ferrer-Salat Serra de Migui  2004
# 176140                    Leire Olaberria Dorronsoro  2008
# 168691                         Silvia Navarro Jimnez  2012
# 189056                   Elisabeth "Eli" Pinedo Senz  2012
# ...

# %%
# Filtrar por NOC de España, medallas de bronce y sexo femenino
df_esp_medallas_bronze_femenino = df[(df['NOC'] == 'ESP') & (df['Medal'] == 'Bronze') & (df['Sex'] == 'F')]

# Seleccionar las columnas relevantes y ordenar por el año
medallistas_bronze_femeninos_sorted = df_esp_medallas_bronze_femenino[['Name', 'Year', 'Sport', 'Medal']].sort_values(by='Year')

medallistas_bronze_femeninos_sorted
# Out:
#                                                 Name  Year  \
# 68318                          Blanca Fernndez Ochoa  1992
# 209619  Arnzazu Isabel Mara "Arantxa" Snchez Vicario  1992
# 150871                       Conchita Martnez Bernat  1996
# 224767                         Yolanda Soler Grajera  1996
# 209622  Arnzazu Isabel Mara "Arantxa" Snchez Vicario  1996
# 68165                  Mara Isabel Fernndez Gutirrez  1996
# 250302              Mara del Monte Vasc Pes Gallardo  2000
# 269334     Nina Alexandrovna Zhivanevskaya Ilichiova  2000
# 73986                Margarita "Marga" Fullana Riera  2000
# 163298                        Patricia Moreno Snchez  2004
# 68631            Beatriz Ferrer-Salat Serra de Migui  2004
# 176140                    Leire Olaberria Dorronsoro  2008
# 168691                         Silvia Navarro Jimnez  2012
# 189056                   Elisabeth "Eli" Pinedo Senz  2012
# 150556                Carmen Dolores Martn Berenguer  2012
# ...

# %%
# Filtrar por NOC de España y sexo femenino
df_esp_femenino = df[(df['NOC'] == 'ESP') & (df['Sex'] == 'F') & (df['Medal'].notna())]

# Contar el número de medallistas en cada categoría
medallistas_por_categoria = df_esp_femenino.groupby('Medal')['Name'].nunique().reset_index(name='Numero de Medallistas')

print("Número de Medallistas Femeninas de España por Categoría de Medalla:")
print(medallistas_por_categoria)
# Out:
# Número de Medallistas Femeninas de España por Categoría de Medalla:
#     Medal  Numero de Medallistas
# 0  Bronze                     38
# 1    Gold                     35
# 2  Silver                     50

# %%
# Filtrar por NOC de España y sexo femenino
df_esp_femenino = df[(df['NOC'] == 'ESP') & (df['Sex'] == 'F') & (df['Medal'].notna())]

# Contar el número de medallistas en cada categoría
medallistas_por_categoria = df_esp_femenino.groupby('Medal')['Name'].nunique().reset_index(name='Numero de Medallistas')

medallistas_por_categoria
# Out:
#     Medal  Numero de Medallistas
# 0  Bronze                     38
# 1    Gold                     35
# 2  Silver                     50

# %%
# Filtrar por NOC de España y sexo femenino
df_esp_femenino = df[(df['NOC'] == 'ESP') & (df['Sex'] == 'F') & (df['Medal'].notna())]

# Contar el número de medallistas en cada deporte y categoría de medalla
medallistas_por_deporte_categoria = df_esp_femenino.groupby(['Sport', 'Medal'])['Name'].nunique().reset_index(name='Numero de Medallistas')

print("Número de Medallistas Femeninas de España por Deporte y Categoría de Medalla:")
print(medallistas_por_deporte_categoria)
# Out:
# Número de Medallistas Femeninas de España por Deporte y Categoría de Medalla:
#                     Sport   Medal  Numero de Medallistas
# 0           Alpine Skiing  Bronze                      1
# 1               Athletics  Bronze                      1
# 2               Athletics    Gold                      1
# 3               Badminton    Gold                      1
# 4              Basketball  Silver                     12
# 5                Canoeing  Bronze                      1
# 6                Canoeing    Gold                      1
# 7                 Cycling  Bronze                      2
# 8           Equestrianism  Bronze                      1
# 9           Equestrianism  Silver                      1
# 10             Gymnastics  Bronze                      1
# 11               Handball  Bronze                     15
# 12                 Hockey    Gold                     15
# 13                   Judo  Bronze                      2
# ...

# %%
# Contar el número de medallistas en cada deporte y categoría de medalla
medallistas_por_deporte_categoria = df_esp_femenino.groupby(['Sport', 'Medal'])['Name'].nunique().reset_index(name='Numero de Medallistas')

medallistas_por_deporte_categoria
# Out:
#                     Sport   Medal  Numero de Medallistas
# 0           Alpine Skiing  Bronze                      1
# 1               Athletics  Bronze                      1
# 2               Athletics    Gold                      1
# 3               Badminton    Gold                      1
# 4              Basketball  Silver                     12
# 5                Canoeing  Bronze                      1
# 6                Canoeing    Gold                      1
# 7                 Cycling  Bronze                      2
# 8           Equestrianism  Bronze                      1
# 9           Equestrianism  Silver                      1
# 10             Gymnastics  Bronze                      1
# 11               Handball  Bronze                     15
# 12                 Hockey    Gold                     15
# 13                   Judo  Bronze                      2
# 14                   Judo    Gold                      3
# ...
